# %% [markdown]
# # Classification with K-Folding

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.inspection import permutation_importance
import os

# %%
perm_df = pd.read_csv("perm_feature_sets_kbest.csv")
coral_df = pd.read_csv("/work/hs325/World_Corals/Cleaned data CSVs/qc_data.csv")
met_df = pd.read_csv("/work/hs325/World_Corals/Cleaned data CSVs/merged_met_plot_df.csv")

## coral_only
coral_df['scleractinia'] = np.where(coral_df['host_order'] == 'Scleractinia', 1, 0)
met_df['refined_origin'] = met_df['refined_origin'].str.replace('Host', 'Coral')
met_df_coral = met_df[met_df['refined_origin'] == 'Coral']

## all
coral_df['scleractinia'] = np.where(coral_df['host_order'] == 'Scleractinia', 1, 0)
met_df['refined_origin'] = met_df['refined_origin'].str.replace('Host', 'Coral')
met_df_all = met_df

y = coral_df['scleractinia']
# Out:
# /tmp/ipykernel_2807585/2652058811.py:2: DtypeWarning: Columns (8,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   coral_df = pd.read_csv("/work/hs325/World_Corals/Cleaned data CSVs/qc_data.csv")

# %% [markdown]
# ### feature sets (X) to test
# coral_only: met_df_coral, perm_df['coralonly_rf'], and perm_df['coralonly_gb']
# all: met_df_all, perm_df['all_rfgb']
#
# procedure:
# for each feature set, do a StratifiedKFold with 5-folds and 80/20 train test so every row in the dataframe is held out test data once
# for each feature set, train a RandomForestClassifier and a XGBClassifier
# for each feature set and model architecture, record the prediction accuracy and confusion matrix for the overall model across all folds
# for each feature set, record any missed classifications by returning the entire row in the original coral_df (this has information   about metadata like species and location)

# %%
coral_df['scleractinia'] = np.where(coral_df['host_order'] == 'Scleractinia', 1, 0)
met_df['refined_origin'] = met_df['refined_origin'].str.replace('Host', 'Coral')
y = coral_df['scleractinia']

# metabolites to use
coral_origin_mets = [m for m in met_df[met_df['refined_origin'] == 'Coral']['metabolite'].unique() if m in coral_df.columns]
all_origin_mets = [m for m in met_df['metabolite'].unique() if m in coral_df.columns]

# all feature scenarios to test
scenarios = {
    "All KBest": [m for m in perm_df['all_500'].dropna() if m in all_origin_mets],
    "Host KBest": [m for m in perm_df['coralonly_500'].dropna() if m in coral_origin_mets],
    "Host Full": coral_origin_mets,
    # "All RF/XGB": [m for m in perm_df['all_rfgb'].dropna() if m in all_origin_mets],
    "All Full": all_origin_mets
}

models_to_run = {
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=123),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=123)
}

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
final_metrics = []
all_missed_dfs = []

for s_name, feat_list in scenarios.items():    
    X = coral_df[feat_list].fillna(0)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    for m_name, model in models_to_run.items():
        run_id = f"{s_name}_{m_name}"
        print(f"Running: {run_id} with ({len(feat_list)} features)")
        
        y_pred = cross_val_predict(model, X, y, cv=skf)
        
        # record performance
        acc = accuracy_score(y, y_pred)
        final_metrics.append({'run': run_id, 'accuracy': acc})
        
        # record missed classifications
        missed_mask = (y != y_pred)
        if missed_mask.any():
            missed_df = coral_df[missed_mask].copy()
            missed_df['missed_on_run'] = run_id
            missed_df['predicted_label'] = y_pred[missed_mask]
            all_missed_dfs.append(missed_df)

# combine all missed rows into one  dataframe
master_missed_df = pd.concat(all_missed_dfs, ignore_index=True)

summary_df = pd.DataFrame(final_metrics)
summary_df
# Out:
# Running: All KBest_RandomForest with (13 features)
# Running: All KBest_XGBoost with (13 features)
# Running: Host KBest_RandomForest with (42 features)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:04] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Running: Host KBest_XGBoost with (42 features)
# Running: Host Full_RandomForest with (3623 features)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:05] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Running: Host Full_XGBoost with (3623 features)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Running: All Full_RandomForest with (16368 features)
# Running: All Full_XGBoost with (16368 features)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:18] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:21] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:25] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#                        run  accuracy
# 0   All KBest_RandomForest  0.945423
# 1        All KBest_XGBoost  0.940141
# 2  Host KBest_RandomForest  0.994718
# 3       Host KBest_XGBoost  0.991197
# 4   Host Full_RandomForest  1.000000
# 5        Host Full_XGBoost  0.998239
# 6    All Full_RandomForest  0.998239
# 7         All Full_XGBoost  0.998239

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_predict

n_total_runs = len(scenarios) * len(models_to_run)
# Set figure for slide dimensions 
fig, axes = plt.subplots(2, 4, figsize=(11.5, 8)) 
axes = axes.flatten()
plot_idx = 0

final_metrics = []
all_missed_dfs = []

for s_name, feat_list in scenarios.items():    
    X = coral_df[feat_list].fillna(0)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    for m_name, model in models_to_run.items():
        run_id = f"{s_name}_{m_name}"
        print(f"Running: {run_id}...")
        
        y_pred = cross_val_predict(model, X, y, cv=skf)
        
        acc = accuracy_score(y, y_pred)
        cm = confusion_matrix(y, y_pred)
        final_metrics.append({'run': run_id, 'accuracy': acc})
        
        missed_mask = (y != y_pred)
        if missed_mask.any():
            missed_df = coral_df[missed_mask].copy()
            missed_df['missed_on_run'] = run_id
            missed_df['predicted_label'] = y_pred[missed_mask]
            all_missed_dfs.append(missed_df)

        ax = axes[plot_idx]
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax, cbar=False, annot_kws={"size": 12})
        
        display_title = run_id.replace('_', ' ')
        ax.set_title(f"{display_title}\nAcc: {acc:.3f}", fontsize=9)
        ax.set_xticklabels(['Other', 'Scleractinia'], fontsize=8)
        ax.set_yticklabels(['Other', 'Scleractinia'], fontsize=8)
        ax.tick_params(axis='both', which='major', labelsize=8)
        
        plot_idx += 1

# Delete any unused subplots if runs < desired #
for i in range(plot_idx, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
save_path = "/work/hs325/World_Corals/misc/figs/cmatrices.jpg"
os.makedirs(os.path.dirname(save_path), exist_ok=True)
plt.savefig(save_path, dpi=300, bbox_inches='tight')
plt.show()

print(f"saved fig to: {save_path}")
master_missed_df = pd.concat(all_missed_dfs, ignore_index=True)
# Out:
# Running: All KBest_RandomForest...
# Running: All KBest_XGBoost...
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:34] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Running: Host KBest_RandomForest...
# Running: Host KBest_XGBoost...
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:35] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Running: Host Full_RandomForest...
# Running: Host Full_XGBoost...
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:37] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:39] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Running: All Full_RandomForest...
# Running: All Full_XGBoost...
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:45] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:49] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:49:56] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:00] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# saved fig to: /work/hs325/World_Corals/misc/figs/cmatrices.jpg

# %%
master_missed_df[['host_phylum', 'host_order', 'host_genus', 'host_species', 'missed_on_run', 'predicted_label']]
# Out:
#    host_phylum        host_order      host_genus host_species  \
# 0     Cnidaria      Scleractinia     Montastraea    cavernosa
# 1     Cnidaria      Scleractinia     Montastraea    cavernosa
# 2     Cnidaria      Scleractinia  Stephanocoenia   intersepta
# 3     Cnidaria      Scleractinia     Siderastrea      siderea
# 4     Cnidaria      Scleractinia       Orbicella    faveolata
# ..         ...               ...             ...          ...
# 71    Cnidaria  Corallimorpharia             NaN          NaN
# 72    Cnidaria        Actiniaria     Bartholomea     annulata
# 73    Cnidaria      Scleractinia         Oculina     varicosa
# 74    Cnidaria      Scleractinia         Oculina     varicosa
# 75    Cnidaria      Scleractinia         Oculina     varicosa
#
#              missed_on_run  predicted_label
# 0   All KBest_RandomForest                0
# 1   All KBest_RandomForest                0
# 2   All KBest_RandomForest                0
# 3   All KBest_RandomForest                0
# 4   All KBest_RandomForest                0
# ..                     ...              ...
# 71      Host KBest_XGBoost                1
# 72      Host KBest_XGBoost                1
# 73       Host Full_XGBoost                0
# 74   All Full_RandomForest                0
# 75        All Full_XGBoost                0
#
# [76 rows x 6 columns]

# %% [markdown]
# # Permutation importance

# %%
## compute permutation importance on each feature set now for the reduced feature sets
## assume the coraldf, metdf, permdf are already defined and packages already loaded

coral_df['scleractinia'] = np.where(coral_df['host_order'] == 'Scleractinia', 1, 0)
met_df['refined_origin'] = met_df['refined_origin'].str.replace('Host', 'Coral')
y = coral_df['scleractinia']

# metabolites to use
coral_origin_mets = [m for m in met_df[met_df['refined_origin'] == 'Coral']['metabolite'].unique() if m in coral_df.columns]
all_origin_mets = [m for m in met_df['metabolite'].unique() if m in coral_df.columns]

# all feature scenarios to test
scenarios = {
    "All_KBest": [m for m in perm_df['all_500'].dropna() if m in all_origin_mets],
    "Host_KBest": [m for m in perm_df['coralonly_500'].dropna() if m in coral_origin_mets],
}

models_to_run = {
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=123),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=123)
}

# %%
importance_results = {}

# Set up the plotting grid (3 scenarios x 2 models = 6 plots)
fig, axes = plt.subplots(len(scenarios), len(models_to_run), figsize=(12, 8))
axes = axes.flatten()
plot_idx = 0

for s_name, feat_list in scenarios.items():
    X = coral_df[feat_list].fillna(0)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.20, stratify=y, random_state=123
    )
    
    for m_name, model in models_to_run.items():
        run_id = f"{s_name}_{m_name}"
        print(f"Computing Permutation Importance for: {run_id}")
        
        # fit model and compute perm importance
        model.fit(X_train, y_train)
        r = permutation_importance(model, X_test, y_test,
                                   n_repeats=30,
                                   random_state=123,
                                   n_jobs=-1)
        
        sorted_idx = r.importances_mean.argsort()[::-1] # Sort descending
        top_indices = sorted_idx[:20] # Show top 20 for clarity if list is long
        # top_indices = sorted_idx

        importances_df = pd.DataFrame(
            r.importances[top_indices].T,
            columns=np.array(feat_list)[top_indices]
        )
        
        # plot
        ax = axes[plot_idx]
        sns.boxplot(data=importances_df, orient='h', ax=ax, palette="viridis", fliersize=1)
        ax.set_title(f"Permutation Importance: {run_id}", fontsize=10)
        ax.set_xlabel("Decrease in Accuracy Score", fontsize=9)
        ax.tick_params(labelsize=8)
        
        plot_idx += 1

# display and optionally save
plt.tight_layout()
plt.show()
# imp_save_path = "/work/hs325/World_Corals/misc/figs/permutation_importance_reduced.jpg"
# os.makedirs(os.path.dirname(imp_save_path), exist_ok=True)
# plt.savefig(imp_save_path, dpi=300, bbox_inches='tight')
# Out:
# Computing Permutation Importance for: All_KBest_RandomForest
# Computing Permutation Importance for: All_KBest_XGBoost
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:19] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Computing Permutation Importance for: Host_KBest_RandomForest
# Computing Permutation Importance for: Host_KBest_XGBoost
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:21] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
import pandas as pd
import numpy as np
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Container for the numerical results
importance_list = []

fig, axes = plt.subplots(len(scenarios), len(models_to_run), figsize=(12, 12))
axes = axes.flatten()
plot_idx = 0

for s_name, feat_list in scenarios.items():
    X = coral_df[feat_list].fillna(0)
    
    # Stratified split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.20, stratify=y, random_state=123
    )
    
    # Scale within the loop to avoid leakage
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    for m_name, model in models_to_run.items():
        run_id = f"{s_name}_{m_name}"
        print(f"Computing Permutation Importance for: {run_id}")
        
        model.fit(X_train_scaled, y_train)
        r = permutation_importance(model, X_test_scaled, y_test,
                                   n_repeats=30,
                                   random_state=123,
                                   n_jobs=-1)
        
        # retain all metabolites
        for i in range(len(feat_list)):
            importance_list.append({
                'metabolite': feat_list[i],
                'importance_mean': r.importances_mean[i],
                'importance_std': r.importances_std[i],
                'feature_set': s_name,
                'model': m_name
            })

        # plot only top 20 metabolites just for clarity
        sorted_idx = r.importances_mean.argsort()[::-1]
        top_indices = sorted_idx[:20]
        
        importances_df = pd.DataFrame(
            r.importances[top_indices].T,
            columns=np.array(feat_list)[top_indices]
        )
        
        ax = axes[plot_idx]
        sns.boxplot(data=importances_df, orient='h', ax=ax, palette="viridis", fliersize=1)
        ax.set_title(f"{run_id}", fontsize=10)
        ax.set_xlabel("Accuracy Decrease", fontsize=8)
        ax.tick_params(labelsize=8)
        plot_idx += 1

# Create the final results DataFrame
perm_results_df = pd.DataFrame(importance_list)

# Display and optionally save Plot
plt.tight_layout()
plt.show()
# imp_save_path = "/work/hs325/World_Corals/misc/figs/permutation_importance_reduced.jpg"
# os.makedirs(os.path.dirname(imp_save_path), exist_ok=True)
# plt.savefig(imp_save_path, dpi=300, bbox_inches='tight')

# Display the top of the new dataframe
print(perm_results_df.sort_values(by='importance_mean', ascending=False).head())
# Out:
# Computing Permutation Importance for: All_KBest_RandomForest
# Computing Permutation Importance for: All_KBest_XGBoost
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:22] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Computing Permutation Importance for: Host_KBest_RandomForest
# Computing Permutation Importance for: Host_KBest_XGBoost
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:24] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#                  metabolite  importance_mean  importance_std feature_set  \
# 85  x31046_620_59826_13_466         0.183333        0.028770  Host_KBest
# 91   x34772_648_7388_14_298         0.049415        0.014232  Host_KBest
# 49   x34772_648_7388_14_298         0.046199        0.013764  Host_KBest
# 43  x31046_620_59826_13_466         0.042105        0.010956  Host_KBest
# 13   x19344_800_60417_9_097         0.038012        0.021166   All_KBest
#
#            model
# 85       XGBoost
# 91       XGBoost
# 49  RandomForest
# 43  RandomForest
# 13       XGBoost

# %% [markdown]
# #### Save results

# %%
perm_results_df
# Out:
#                   metabolite  importance_mean  importance_std feature_set  \
# 0     x19344_800_60417_9_097         0.035380        0.017172   All_KBest
# 1    x22863_768_59077_10_971         0.027485        0.009803   All_KBest
# 2      x3156_482_36064_2_937         0.021345        0.009524   All_KBest
# 3     x19279_643_51751_9_054         0.026608        0.010976   All_KBest
# 4      x6124_510_39212_3_959         0.013743        0.006278   All_KBest
# ..                       ...              ...             ...         ...
# 105  x21817_804_58699_10_362         0.000000        0.000000  Host_KBest
# 106   x15214_800_50547_7_387        -0.001462        0.005107  Host_KBest
# 107    x2601_401_34489_2_466         0.000000        0.000000  Host_KBest
# 108  x24266_681_50699_11_696         0.000000        0.000000  Host_KBest
# 109   x15248_654_56589_7_434        -0.007895        0.002632  Host_KBest
#
#             model
# 0    RandomForest
# 1    RandomForest
# 2    RandomForest
# 3    RandomForest
# 4    RandomForest
# ..            ...
# 105       XGBoost
# 106       XGBoost
# 107       XGBoost
# 108       XGBoost
# 109       XGBoost
#
# [110 rows x 5 columns]

# %%
perm_results_df.to_csv("perm_importance_results_kbest.csv")
master_missed_df[['host_phylum', 'host_order', 'host_genus', 'host_species', 'missed_on_run', 'predicted_label']].to_csv("missed_classifs_kbest.csv")
